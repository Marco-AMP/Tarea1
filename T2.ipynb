# %%
import pandas as pd

# %%
# %pip install pandas
# Out:
# ...
#      --------------------------------------- 10.3/10.3 MB 14.5 MB/s eta 0:00:00
# ...
#      ------------------------------------- 499.4/499.4 kB 30.6 MB/s eta 0:00:00
# ...
#      --------------------------------------- 14.8/14.8 MB 26.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys

# %%
import os
os.chdir("C:\\Users\\Marco\\Desktop\\Semestre2023_2\\Programacion\\Tarea1\\Resultado")
os.getcwd()

import csv
f= open("POB_TOT.csv")
reader = csv.reader(f)
for row in reader:
    #print (row)
# Out:
#   Cell In[10], line 9
#     #print (row)
#                 ^
# SyntaxError: incomplete input

# %%
poblacion=pd.read_csv('POB_TOT.csv', header=0)
poblacionnew=poblacion.iloc[:,4:67]
pais= poblacion.iloc[:,0]
poblacionnew=poblacionnew.assign(CountryName=pais)
print(poblacionnew)
#poblacionnew.to_csv('New_POB_TOT')
# Out:
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# 1    130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2      8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3     97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4      5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
# ..           ...          ...          ...          ...          ...
# 261     947000.0     966000.0     994000.0    1022000.0    1050000.0
# 262    5542459.0    5646668.0    5753386.0    5860197.0    5973803.0
# 263   16520441.0   16989464.0   17503133.0   18042215.0   18603097.0
# 264    3119430.0    3219451.0    3323427.0    3431381.0    3542764.0
# 265    3806310.0    3925952.0    4049778.0    4177931.0    4310332.0
#
#             1965         1966         1967         1968         1969  ...  \
# ...

# %%
r= poblacionnew[['2021','CountryName']]

# %%
r.sort_values(by='2021')
# Out:
#              2021               CountryName
# 245  1.120400e+04                    Tuvalu
# 179  1.251100e+04                     Nauru
# 188  1.802400e+04                     Palau
# 255  3.112200e+04    British Virgin Islands
# 147  3.194800e+04  St. Martin (French part)
# ..            ...                       ...
# 156  5.901324e+09             Middle income
# 140  6.619579e+09       Low & middle income
# 103  6.695398e+09          IDA & IBRD total
# 259  7.888409e+09                     World
# 110           NaN            Not classified
#
# [266 rows x 2 columns]

# %%
poblacionnew
# Out:
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# 1    130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2      8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3     97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4      5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
# ..           ...          ...          ...          ...          ...
# 261     947000.0     966000.0     994000.0    1022000.0    1050000.0
# 262    5542459.0    5646668.0    5753386.0    5860197.0    5973803.0
# 263   16520441.0   16989464.0   17503133.0   18042215.0   18603097.0
# 264    3119430.0    3219451.0    3323427.0    3431381.0    3542764.0
# 265    3806310.0    3925952.0    4049778.0    4177931.0    4310332.0
#
#             1965         1966         1967         1968         1969  ...  \
# ...

# %%
p= pd.read_csv('paises.csv')
p= p[['name']]
p
# Out:
#                   name
# 0          Afghanistan
# 1              Albania
# 2              Germany
# 3              Algeria
# 4              Andorra
# ..                 ...
# 241  Wallis and Futuna
# 242              Yemen
# 243           Djibouti
# 244             Zambia
# 245           Zimbabwe
#
# [246 rows x 1 columns]

# %%
poblacionnew
# Out:
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# 1    130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2      8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3     97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4      5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
# ..           ...          ...          ...          ...          ...
# 261     947000.0     966000.0     994000.0    1022000.0    1050000.0
# 262    5542459.0    5646668.0    5753386.0    5860197.0    5973803.0
# 263   16520441.0   16989464.0   17503133.0   18042215.0   18603097.0
# 264    3119430.0    3219451.0    3323427.0    3431381.0    3542764.0
# 265    3806310.0    3925952.0    4049778.0    4177931.0    4310332.0
#
#             1965         1966         1967         1968         1969  ...  \
# ...

# %%
filtro = poblacionnew[poblacionnew.CountryName.isin(p.name)]

# %%
r2= filtro[['2021','CountryName']]

# %%
r2= r2.sort_values(by='2021', ascending=False)

# %%
top10= r2.iloc[0:10]
top10
# Out:
#              2021 CountryName
# 40   1.412360e+09       China
# 109  1.407564e+09       India
# 106  2.737532e+08   Indonesia
# 184  2.314021e+08    Pakistan
# 29   2.143262e+08      Brazil
# 174  2.134013e+08     Nigeria
# 20   1.693563e+08  Bangladesh
# 154  1.267051e+08      Mexico
# 119  1.256816e+08       Japan
# 72   1.202830e+08    Ethiopia

# %%
import matplotlib.pyplot as plt

# %%
grafica= pd.read_csv('PaEditar.csv')
grafica
# Out:
#          2021 CountryName  Num
# 0  1412360000       China    1
# 1  1407563842       India    2
# 2   273753191   Indonesia    3
# 3   231402117    Pakistan    4
# 4   214326223      Brazil    5
# 5   213401323     Nigeria    6
# 6   169356251  Bangladesh    7
# 7   126705138      Mexico    8
# 8   125681593       Japan    9
# 9   120283026    Ethiopia   10

# %%
x= grafica['Num']
y= grafica['2021'] 

plt.plot(x,y)
plt.show()
